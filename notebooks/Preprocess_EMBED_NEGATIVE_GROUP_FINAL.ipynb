# %% [markdown]
# # DATASET CURATION - MASKED ROI PROJECT
#
#
# **Objectives**:
#
# To create the following groups:
# 1. **Positive group**: BIRADS 0 that became BIRADS 3, 4, 5, 6 in the subsequent diagnostic study
# 2. **Negative group**: BIRADS 1, 2 and BIRADS 0 that became BIRADS 1, 2 in the subsequent diagnostic study

# %% [markdown]
# ## 1. Prep

# %%
import pandas as pd
import numpy as np
import random
from tqdm import tqdm

from IPython.display import display

pd.set_option("display.max_rows", 50)
pd.set_option("display.max_columns", 500)

# %%
def get_stats(df, suffix=None):
    """Provides a quick summary of a dataframe."""
    try:
        print(f"DF shape: {df.shape}")
        print(f"# Patients: {df.empi_anon.nunique()}")
        print(f"# Cases: {df.acc_anon.nunique()}\n")
        print(f"# Images: {df.anon_dicom_path.nunique()}\n")
    except Exception as e:
        print(e)

# %%
# EMBED
magview_path = "/content/EMBED_OpenData_clinical.csv"
metadata_path = "/content/EMBED_OpenData_metadata.csv"


metadata_full = pd.read_csv(metadata_path, dtype=str)
magview_full = pd.read_csv(magview_path, dtype=str)

# %%
# Selecting the following columns

meta_cols = [
    "empi_anon",
    "acc_anon",
    "ImageLateralityFinal",
    "ViewPosition",
    "study_date_anon",
    "FinalImageType",
    "anon_dicom_path",
    "png_path",
    "StudyDescription",
    "ProtocolName",
    "match_level",
    "num_roi",
    "ROI_coords",
    "BreastImplantPresent",
]

mag_cols = [
    "empi_anon",
    "acc_anon",
    "study_date_anon",
    "desc",
    "side",
    "asses",
    "path_severity",
    "bside",
    "procdate_anon",
    "pdate_anon",
]

# %%
metadata = metadata_full[meta_cols].copy()
magview = magview_full[mag_cols].copy()

# %%
metadata.study_date_anon = pd.to_datetime(metadata.study_date_anon, errors="coerce")
magview.study_date_anon = pd.to_datetime(magview.study_date_anon, errors="coerce")

# %%
# follow_up_period = metadata.groupby('empi_anon')['study_date_anon'].agg(['min', 'max'])
# follow_up_period['duration_years'] = (follow_up_period['max'] - follow_up_period['min']).dt.days / 365.25
# patients_with_5_years  = follow_up_period[follow_up_period['duration_years'] >= 4 ]

# Step 5: Get the patient IDs (empi_anon) that meet the 5-year criteria
# valid_patients = patients_with_5_years.index

# metadata  = metadata[metadata['empi_anon'].isin(valid_patients)].reset_index(drop=True)
# get_stats(metadata)

# %%
metadata["num_roi"] = metadata["num_roi"].fillna(0).astype(int)

metadata.num_roi = metadata.num_roi.astype(int)

# %% [markdown]
# ## 2. METADATA: 2D MLO & CC

# %%
# EMBED 2D (MLO and CC)
meta_2d = metadata.loc[
    (metadata.FinalImageType == "2D") & (metadata.ViewPosition.isin(["MLO", "CC"]))
]
get_stats(meta_2d)
# Out:
# DF shape: (328961, 14)
# # Patients: 22455
# # Cases: 70861
#
# # Images: 328961

# %%
def get_image_stats(df):
    """Provides a quick summary of the number of unique images and the ROIs."""
    temp_df = pd.merge(df, meta_2d, on=["empi_anon", "acc_anon"], how="left")
    temp_df = temp_df.loc[(temp_df.side == temp_df.ImageLateralityFinal)]
    temp_df.drop_duplicates(subset="png_path", inplace=True)
    print(f"# PNG PATH: {int(temp_df.png_path.nunique())}")
    print(f"# ROI: {int(temp_df.num_roi.sum())}")
    print(f"{temp_df.num_roi.value_counts()}")
    del temp_df

# %% [markdown]
# ## 3. Screening

# %%
# SCREENING
screening_magview = magview.loc[magview.desc.str.contains("screen", case=False)].copy()
get_stats(screening_magview)
# Out:
# DF shape: (58888, 10)
# # Patients: 20460
# # Cases: 55956
#
# 'DataFrame' object has no attribute 'png_path'

# %% [markdown]
# ### 3.1. Creating entries for the negative contralateral breast in bilateral examinations
#
# ```
# MAGVIEW only has entries if a finding exists.
#
# This means that if an exam is a bilateral exam and only one of the breast has a finding, the contralateral breast (negative) won't have an entry.
#
# This would be problematic at the time when we need to merge with METADATA, because the contralateral breast would be excluded.
#
# Therefore, we would need to create rows for the negative contralateral breast.
# ```

# %%
def get_exam_laterality(row):
    """A convenient function to get the exam laterality to be used with DF.apply() instead of iterating over each row."""
    if "bilat" in row.desc.lower():
        return "B"
    elif "left" in row.desc.lower():
        return "L"
    elif "right" in row.desc.lower():
        return "R"
    else:
        return None

# %%
# Applying the get_exam_laterality function
screening_magview["exam_laterality"] = screening_magview.apply(
    get_exam_laterality, axis=1
)

# %%
screening_magview.exam_laterality.value_counts(dropna=False)
# Out:
# exam_laterality
# B    56558
# L     1180
# R     1150
# Name: count, dtype: int64

# %%
screening_magview.side.value_counts(dropna=False)
# Out:
# side
# NaN    39661
# L       8264
# R       8082
# B       2881
# Name: count, dtype: int64

# %%
# side == nan --> B
screening_magview.side = screening_magview.side.fillna("B")

# %%
# create copy for assigning B to R
screening_magview_r = screening_magview.loc[screening_magview.side == "B"].copy()
screening_magview_r.side = screening_magview.side.str.replace("B", "R")

# assigning B to L
screening_magview.side = screening_magview.side.str.replace("B", "L")

# appending R and L
screening_magview = pd.concat([screening_magview, screening_magview_r])

# %%
print(screening_magview.side.value_counts(dropna=False))
print(screening_magview.shape)
# Out:
# side
# L    50806
# R    50624
# Name: count, dtype: int64
# (101430, 11)

# %%
screening_magview = screening_magview.sort_values(
    ["empi_anon", "acc_anon", "study_date_anon"]
).drop_duplicates()
screening_magview
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 31489  10000879  6992096043050201      2018-02-16
# 31489  10000879  6992096043050201      2018-02-16
# 10198  10009146  4190527469809995      2014-07-04
# 10198  10009146  4190527469809995      2014-07-04
# 20474  10015693  1334581155737139      2015-10-11
# ...         ...               ...             ...
# 21119  99996622  9655172659462321      2016-06-04
# 25708  99999564  4369225803558884      2017-04-25
# 25708  99999564  4369225803558884      2017-04-25
# 31493  99999564  8832872399780580      2019-02-27
# 31493  99999564  8832872399780580      2019-02-27
#
#                                            desc side asses path_severity  \
# 31489  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 31489  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 10198  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 10198  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 20474  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     A           NaN
# ...                                         ...  ...   ...           ...
# 21119  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 25708  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 25708  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 31493  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 31493  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality
# 31489   NaN           NaN        NaN               B
# 31489   NaN           NaN        NaN               B
# 10198   NaN           NaN        NaN               B
# 10198   NaN           NaN        NaN               B
# 20474   NaN           NaN        NaN               B
# ...     ...           ...        ...             ...
# 21119   NaN           NaN        NaN               B
# 25708   NaN           NaN        NaN               B
# 25708   NaN           NaN        NaN               B
# 31493   NaN           NaN        NaN               B
# 31493   NaN           NaN        NaN               B
#
# [100120 rows x 11 columns]

# %%
exam_lat_b = screening_magview.loc[screening_magview.exam_laterality == "B"]
exam_lat_b.sample(2)
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 4944   74149616  9910167524120421      2014-09-28
# 50818  95378407  2439012505154554      2015-03-08
#
#                                            desc side asses path_severity  \
# 4944   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 50818                    MG Screening Bilateral    R     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality
# 4944    NaN           NaN        NaN               B
# 50818   NaN           NaN        NaN               B

# %%
# We want to aggregate all the sides for each bilateral exam so that we can filter those having only a single side.
exam_lat_b_agg = exam_lat_b.groupby("acc_anon")["side"].apply("".join).reset_index()
exam_lat_b_agg.sample(2)
# Out:
#                acc_anon side
# 26037  5330330563068999   LR
# 15500  3567917562128811   LR

# %%
exam_lat_b_agg.side.value_counts()
# Out:
# side
# LR        42769
# L          4938
# R          4882
# RL          615
# LL          123
# RR          114
# LLR          75
# LRR          43
# RLR          25
# LLRR         20
# RRL          16
# RLL          12
# LLL          11
# LRL           5
# RLLR          5
# RRR           4
# LRLR          4
# RRLL          3
# RRLR          2
# LLLRRR        2
# LRRR          1
# RRRR          1
# LLRRR         1
# LLLLLR        1
# LLLRR         1
# LLLR          1
# RRRLLL        1
# LRRL          1
# Name: count, dtype: int64

# %%
exam_lat_b_side_r = exam_lat_b_agg.loc[~(exam_lat_b_agg.side.str.contains("L"))].copy()
exam_lat_b_side_l = exam_lat_b_agg.loc[~(exam_lat_b_agg.side.str.contains("R"))].copy()

# %%
screening_magview_right_to_left = (
    screening_magview.loc[screening_magview.acc_anon.isin(exam_lat_b_side_r.acc_anon)]
    .copy()
    .drop_duplicates()
)
screening_magview_left_to_right = (
    screening_magview.loc[screening_magview.acc_anon.isin(exam_lat_b_side_l.acc_anon)]
    .copy()
    .drop_duplicates()
)

# %%
# Creating the negative Left side
screening_magview_right_to_left.loc[
    screening_magview_right_to_left.side == "R", "side"
] = "L"
screening_magview_right_to_left.loc[
    screening_magview_right_to_left.side == "L", "asses"
] = "N"
screening_magview_right_to_left.loc[
    screening_magview_right_to_left.side == "L", "path_severity"
] = np.nan

screening_magview_right_to_left
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 37325  10033806  1069386741434572      2019-10-05
# 64534  10043985  1960584382049532      2018-04-18
# 59088  10043985  3613575521057039      2017-03-01
# 42847  10043985  9492972692582499      2014-05-14
# 8607   10065082  6346759651734606      2015-03-03
# ...         ...               ...             ...
# 11436  99853035  2905584160156737      2015-02-15
# 33776  99853035  6677454260490853      2019-02-07
# 67642  99860105  6470240272862407      2018-03-19
# 12820  99871644  5176060292067455      2015-06-26
# 73727  99935792  7342511220486189      2019-02-20
#
#                                            desc side asses path_severity  \
# 37325  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 64534  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 59088                    MG Screening Bilateral    L     N           NaN
# 42847                    MG Screening Bilateral    L     N           NaN
# 8607   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# ...                                         ...  ...   ...           ...
# 11436  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 33776  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 67642  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 12820                    MG Screening Bilateral    L     N           NaN
# 73727  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality
# 37325   NaN           NaN        NaN               B
# 64534   NaN           NaN        NaN               B
# 59088   NaN           NaN        NaN               B
# 42847   NaN           NaN        NaN               B
# 8607    NaN           NaN        NaN               B
# ...     ...           ...        ...             ...
# 11436   NaN           NaN        NaN               B
# 33776   NaN           NaN        NaN               B
# 67642   NaN           NaN        NaN               B
# 12820   NaN           NaN        NaN               B
# 73727   NaN           NaN        NaN               B
#
# [5126 rows x 11 columns]

# %%
# Creating the negative Right side
screening_magview_left_to_right.loc[
    screening_magview_left_to_right.side == "L", "side"
] = "R"
screening_magview_left_to_right.loc[
    screening_magview_left_to_right.side == "R", "asses"
] = "N"
screening_magview_left_to_right.loc[
    screening_magview_left_to_right.side == "R", "path_severity"
] = np.nan

screening_magview_left_to_right
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 20474  10015693  1334581155737139      2015-10-11
# 25070  10023113  5135241747022662      2016-10-05
# 63407  10029585  3189592535497441      2017-06-11
# 62320  10042753  1955284757719450      2017-06-15
# 37004  10044241  3993319361430024      2019-07-27
# ...         ...               ...             ...
# 80934  99881569  1140879824262422      2021-01-05
# 43901  99881569  3921887412575009      2013-11-02
# 9588   99908618  9288525074493489      2014-08-14
# 6519   99957941  2224428804635608      2014-06-03
# 29282  99986224  8107409307566891      2018-05-22
#
#                                            desc side asses path_severity  \
# 20474  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 25070  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 63407  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 62320  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 37004  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# ...                                         ...  ...   ...           ...
# 80934  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 43901              MG Screening Bilateral w/CAD    R     N           NaN
# 9588               MG Screening Bilateral w/CAD    R     N           NaN
# 6519                     MG Screening Bilateral    R     N           NaN
# 29282  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#       bside procdate_anon           pdate_anon exam_laterality
# 20474   NaN           NaN                  NaN               B
# 25070   NaN           NaN                  NaN               B
# 63407   NaN           NaN                  NaN               B
# 62320   NaN           NaN                  NaN               B
# 37004   NaN           NaN                  NaN               B
# ...     ...           ...                  ...             ...
# 80934   NaN           NaN                  NaN               B
# 43901   NaN           NaN                  NaN               B
# 9588      L    2014-08-26  2014-08-27 00:00:00               B
# 6519    NaN           NaN                  NaN               B
# 29282   NaN           NaN                  NaN               B
#
# [5217 rows x 11 columns]

# %%
# Merging the original and the two negative contralaterals
screening_magview_with_contralat = (
    pd.concat(
        [
            screening_magview,
            screening_magview_left_to_right,
            screening_magview_right_to_left,
        ]
    )
    .sort_values(["empi_anon", "acc_anon", "study_date_anon"])
    .drop_duplicates()
)
screening_magview_with_contralat.sample(2)
screening_magview_with_contralat.to_csv(
    "/content/EMBED_OpenData_magview_with_controlateral.csv", index=False
)

# %%
get_stats(meta_2d)
# Out:
# DF shape: (328961, 14)
# # Patients: 22455
# # Cases: 70861
#
# # Images: 328961

# %%
get_stats(screening_magview_with_contralat)
display(screening_magview_with_contralat)
# Out:
# DF shape: (110396, 11)
# # Patients: 20460
# # Cases: 55956
#
# 'DataFrame' object has no attribute 'png_path'
#       empi_anon          acc_anon study_date_anon  \
# 31489  10000879  6992096043050201      2018-02-16
# 31489  10000879  6992096043050201      2018-02-16
# 10198  10009146  4190527469809995      2014-07-04
# 10198  10009146  4190527469809995      2014-07-04
# 20474  10015693  1334581155737139      2015-10-11
# ...         ...               ...             ...
# 21119  99996622  9655172659462321      2016-06-04
# 25708  99999564  4369225803558884      2017-04-25
# 25708  99999564  4369225803558884      2017-04-25
# 31493  99999564  8832872399780580      2019-02-27
# 31493  99999564  8832872399780580      2019-02-27
#
#                                            desc side asses path_severity  \
# 31489  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 31489  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 10198  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 10198  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 20474  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     A           NaN
# ...                                         ...  ...   ...           ...
# 21119  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 25708  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 25708  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 31493  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 31493  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality
# 31489   NaN           NaN        NaN               B
# 31489   NaN           NaN        NaN               B
# 10198   NaN           NaN        NaN               B
# 10198   NaN           NaN        NaN               B
# 20474   NaN           NaN        NaN               B
# ...     ...           ...        ...             ...
# 21119   NaN           NaN        NaN               B
# 25708   NaN           NaN        NaN               B
# 25708   NaN           NaN        NaN               B
# 31493   NaN           NaN        NaN               B
# 31493   NaN           NaN        NaN               B
#
# [110396 rows x 11 columns]

# %%
get_image_stats(screening_magview_with_contralat)
# Out:
# # PNG PATH: 258269
# # ROI: 5255
# num_roi
# 0.0    253498
# 1.0      4330
# 2.0       399
# 3.0        41
# 4.0         1
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2. BIRADS 0

# %%
b0 = screening_magview_with_contralat.loc[
    screening_magview_with_contralat.asses.isin(["A"])
]

get_stats(b0)
get_image_stats(b0)
# Out:
# DF shape: (10876, 11)
# # Patients: 7747
# # Cases: 8829
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 24387
# # ROI: 5131
# num_roi
# 0.0    19725
# 1.0     4232
# 2.0      392
# 3.0       37
# 4.0        1
# Name: count, dtype: int64

# %% [markdown]
# ### 3.3. BIRADS 1, 2

# %%
b12 = screening_magview_with_contralat.loc[
    screening_magview_with_contralat.asses.isin(["B", "N"])
]

get_stats(b12)
get_image_stats(b12)
# Out:
# DF shape: (99482, 11)
# # Patients: 19665
# # Cases: 54081
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 234362
# # ROI: 192
# num_roi
# 0.0    234192
# 1.0       153
# 2.0        12
# 3.0         5
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Diagnostic

# %%
diag_magview = magview.loc[magview.desc.str.contains("diag", case=False)]

get_stats(diag_magview)
print()
print(f"Asses Counts:\n{diag_magview.asses.value_counts()}")
# Out:
# DF shape: (22888, 10)
# # Patients: 9656
# # Cases: 16814
#
# 'DataFrame' object has no attribute 'png_path'
#
# Asses Counts:
# asses
# B    8794
# P    5563
# N    4193
# S    3063
# A     580
# K     386
# M     284
# X      25
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Screening BIRADS 0 and Diagnostic

# %%
b0_dx = pd.merge(b0, diag_magview, on="empi_anon", suffixes=[None, "_dx"])
b0_dx = b0_dx.loc[
    (b0_dx.side == b0_dx.side_dx) | (b0_dx.side_dx == "B") | (b0_dx.side_dx.isna())
]

# %%
# Getting only subsequent diagnostic studies within 3 months
b0_dx["delta_date_dx"] = (b0_dx.study_date_anon_dx - b0_dx.study_date_anon).dt.days
b0_dx_3mo = b0_dx.loc[b0_dx.delta_date_dx.isin(range(0, 91))]
b0_dx_3mo.sample(1)
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 14786  74214316  1279925568980544      2013-03-27
#
#                                desc side asses path_severity bside  \
# 14786  MG Screening Bilateral w/CAD    L     A           2.0     L
#
#       procdate_anon           pdate_anon exam_laterality       acc_anon_dx  \
# 14786    2013-04-17  2013-04-17 00:00:00               B  5095691490562933
#
#       study_date_anon_dx             desc_dx side_dx asses_dx  \
# 14786         2013-04-11  MG Diagnostic Left       L        S
#
#       path_severity_dx bside_dx procdate_anon_dx        pdate_anon_dx  \
# 14786              2.0        L       2013-04-17  2013-04-17 00:00:00
#
#        delta_date_dx
# 14786             15

# %% [markdown]
# ### 5.1. BIRADS 0 (Screening) --> BIRADS 1, 2 (Diagnostic)

# %%
b0_12dx = b0_dx_3mo.loc[b0_dx_3mo.asses_dx.isin(["N", "B"])].copy()
get_stats(b0_12dx)
get_image_stats(b0_12dx)
# Out:
# DF shape: (3755, 21)
# # Patients: 2924
# # Cases: 3169
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 7695
# # ROI: 1676
# num_roi
# 0.0    6212
# 1.0    1306
# 2.0     162
# 3.0      14
# 4.0       1
# Name: count, dtype: int64

# %% [markdown]
# ### 5.2. BIRADS 0 (Screening) --> BIRADS 3, 4, 5, 6 (Diagnostic)

# %%
b0_3456dx = magview.loc[
    magview.asses.isin(["K"]) | magview.path_severity.isin([0, 1])
].copy()

get_stats(b0_3456dx)
get_image_stats(b0_3456dx)
display(b0_3456dx)
# Out:
# DF shape: (395, 10)
# # Patients: 216
# # Cases: 313
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 806
# # ROI: 9
# num_roi
# 0.0    798
# 1.0      7
# 2.0      1
# Name: count, dtype: int64
#       empi_anon          acc_anon study_date_anon  \
# 248    41737961  3103295389430403      2013-01-10
# 249    41737961  3103295389430403      2013-01-10
# 787    82818555  9133832708678084      2013-11-10
# 1151   12628486  8298312705312234      2013-09-05
# 1372   75428728  3608864100750486      2014-01-30
# ...         ...               ...             ...
# 81451  87877516  2183052495313832      2021-01-09
# 81452  87877516  2183052495313832      2021-01-09
# 81453  87877516  2183052495313832      2021-01-09
# 81558  99703607  1965937622916299      2019-12-08
# 81644  85936969  4786838232916669      2019-09-10
#
#                                      desc side asses path_severity bside  \
# 248         MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 249         MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 787         MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 1151                  MG Diagnostic Right    R     K           0.0     R
# 1372                   MG Diagnostic Left    L     K           NaN   NaN
# ...                                   ...  ...   ...           ...   ...
# 81451  MG Diagnostic Bilateral w/Tomo/CAD    L     K           0.0     L
# 81452  MG Diagnostic Bilateral w/Tomo/CAD    L     K           0.0     L
# 81453  MG Diagnostic Bilateral w/Tomo/CAD    L     K           0.0     L
# 81558           MG Diagnostic Right w/CAD    R     K           0.0     R
# 81644           MG Diagnostic Right w/CAD    R     K           0.0     R
#
#       procdate_anon           pdate_anon
# 248             NaN                  NaN
# 249             NaN                  NaN
# 787             NaN                  NaN
# 1151     2013-10-10  2013-10-10 00:00:00
# 1372            NaN                  NaN
# ...             ...                  ...
# 81451    2021-02-15  2021-02-22 00:00:00
# 81452    2021-02-15  2021-02-22 00:00:00
# 81453    2021-02-15  2021-02-22 00:00:00
# 81558    2019-12-29  2020-01-01 00:00:00
# 81644    2019-10-11  2019-10-15 00:00:00
#
# [395 rows x 10 columns]

# %% [markdown]
# ## 6. Negative group

# %%
# Negative group = BIRADS_12 + BIRADS_0_12dx
neg_group = pd.concat([b12, b0_12dx])
neg_group.drop_duplicates(inplace=True)

get_stats(neg_group)
get_image_stats(neg_group)
# Out:
# DF shape: (103023, 21)
# # Patients: 19877
# # Cases: 54639
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 241885
# # ROI: 1860
# num_roi
# 0.0    240240
# 1.0      1451
# 2.0       174
# 3.0        19
# 4.0         1
# Name: count, dtype: int64

# %%
# Include only ones with negative follow-up after 1 year
neg_group_b12 = pd.merge(neg_group, b12, on=["empi_anon"], suffixes=(None, "_1yrfu"))

neg_group_b12 = neg_group_b12.loc[(neg_group_b12.side == neg_group_b12.side_1yrfu)]

neg_group_b12["delta_date_1yrfu"] = (
    neg_group_b12.study_date_anon_1yrfu - neg_group_b12.study_date_anon
).dt.days

get_stats(neg_group_b12)
get_image_stats(neg_group_b12)

neg_group_b12.sample(2)
# Out:
# DF shape: (419008, 32)
# # Patients: 19665
# # Cases: 54427
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 239895
# # ROI: 1287
# num_roi
# 0.0    238741
# 1.0      1034
# 2.0       108
# 3.0        11
# 4.0         1
# Name: count, dtype: int64
#        empi_anon          acc_anon study_date_anon  \
# 389836  53477169  4444852259333890      2017-07-18
# 679030  85642901  5319540478526708      2019-10-09
#
#                                             desc side asses path_severity  \
# 389836  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 679030  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
#
#        bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 389836   NaN           NaN        NaN               B         NaN
# 679030   NaN           NaN        NaN               B         NaN
#
#        study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 389836                NaT     NaN     NaN      NaN              NaN      NaN
# 679030                NaT     NaN     NaN      NaN              NaN      NaN
#
#        procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 389836              NaN           NaN            NaN  8036531341828254
# 679030              NaN           NaN            NaN  4564119800495999
#
#        study_date_anon_1yrfu                                desc_1yrfu  \
# 389836            2019-01-02  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 679030            2015-05-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#        side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 389836          R           N                 NaN         NaN
# 679030          L           N                 NaN         NaN
#
#        procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 389836                 NaN              NaN                     B
# 679030                 NaN              NaN                     B
#
#         delta_date_1yrfu
# 389836               533
# 679030             -1598

# %%
neg_group_1yrfu = neg_group_b12.loc[(neg_group_b12.delta_date_1yrfu > 360)]
get_stats(neg_group_1yrfu)
get_image_stats(neg_group_1yrfu)
# Out:
# DF shape: (158091, 32)
# # Patients: 11590
# # Cases: 34180
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 150887
# # ROI: 690
# num_roi
# 0.0    150266
# 1.0       563
# 2.0        48
# 3.0         9
# 4.0         1
# Name: count, dtype: int64

# %%
neg_group_1yrfu_first_study = neg_group_1yrfu.sort_values(
    ["empi_anon", "acc_anon", "study_date_anon_1yrfu"]
).drop_duplicates(subset=["acc_anon", "side"])  # to only get the first followup study
get_stats(neg_group_1yrfu_first_study)
get_image_stats(neg_group_1yrfu_first_study)
# Out:
# DF shape: (63835, 32)
# # Patients: 11590
# # Cases: 34180
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 150887
# # ROI: 690
# num_roi
# 0.0    150266
# 1.0       563
# 2.0        48
# 3.0         9
# 4.0         1
# Name: count, dtype: int64

# %%
neg_group_1yrfu_first_study.path_severity.value_counts()
# Out:
# path_severity
# 4.0    25
# 2.0     7
# 0.0     4
# 3.0     1
# Name: count, dtype: int64

# %%
# Exclude any patient with any biopsy result
neg_group_1yrfu_first_study_no_biopsy = neg_group_1yrfu_first_study.loc[
    neg_group_1yrfu_first_study.path_severity.isna()
].copy()

# %%
# Merging with METADATA to get the images
neg_group_1yrfu_first_study_no_biopsy_images = pd.merge(
    neg_group_1yrfu_first_study_no_biopsy,
    meta_2d,
    on=["empi_anon", "acc_anon", "study_date_anon"],
)
neg_group_1yrfu_first_study_no_biopsy_images = (
    neg_group_1yrfu_first_study_no_biopsy_images.loc[
        (
            neg_group_1yrfu_first_study_no_biopsy_images.side
            == neg_group_1yrfu_first_study_no_biopsy_images.ImageLateralityFinal
        )
    ]
)
neg_group_1yrfu_first_study_no_biopsy_images.drop_duplicates(
    subset="png_path", inplace=True
)
get_stats(neg_group_1yrfu_first_study_no_biopsy_images)
# Out:
# DF shape: (149727, 43)
# # Patients: 11243
# # Cases: 33180
#
# # Images: 149727

# %%
print(f"ROIs = {neg_group_1yrfu_first_study_no_biopsy_images.num_roi.sum()}")
print(neg_group_1yrfu_first_study_no_biopsy_images.num_roi.value_counts())
# Out:
# ROIs = 678
# num_roi
# 0    149116
# 1       555
# 2        46
# 3         9
# 4         1
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Positive Group

# %%
pos_group_images = pd.merge(
    b0_3456dx, meta_2d, on=["empi_anon", "acc_anon", "study_date_anon"]
)
pos_group_images = pos_group_images.loc[
    (pos_group_images.side == pos_group_images.ImageLateralityFinal)
]
pos_group_images.drop_duplicates(subset="anon_dicom_path", inplace=True)
get_stats(pos_group_images)
display(pos_group_images)
# Out:
# DF shape: (806, 21)
# # Patients: 209
# # Cases: 303
#
# # Images: 806
#      empi_anon          acc_anon study_date_anon  \
# 1     41737961  3103295389430403      2013-01-10
# 4     41737961  3103295389430403      2013-01-10
# 5     41737961  3103295389430403      2013-01-10
# 12    82818555  9133832708678084      2013-11-10
# 13    82818555  9133832708678084      2013-11-10
# ...        ...               ...             ...
# 1492  87877516  2183052495313832      2021-01-09
# 1509  99703607  1965937622916299      2019-12-08
# 1510  99703607  1965937622916299      2019-12-08
# 1511  85936969  4786838232916669      2019-09-10
# 1512  85936969  4786838232916669      2019-09-10
#
#                                     desc side asses path_severity bside  \
# 1          MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 4          MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 5          MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 12         MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 13         MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# ...                                  ...  ...   ...           ...   ...
# 1492  MG Diagnostic Bilateral w/Tomo/CAD    L     K           0.0     L
# 1509           MG Diagnostic Right w/CAD    R     K           0.0     R
# 1510           MG Diagnostic Right w/CAD    R     K           0.0     R
# 1511           MG Diagnostic Right w/CAD    R     K           0.0     R
# 1512           MG Diagnostic Right w/CAD    R     K           0.0     R
#
#      procdate_anon           pdate_anon ImageLateralityFinal ViewPosition  \
# 1              NaN                  NaN                    R           CC
# 4              NaN                  NaN                    R          MLO
# 5              NaN                  NaN                    R          MLO
# 12             NaN                  NaN                    R           CC
# 13             NaN                  NaN                    R           CC
# ...            ...                  ...                  ...          ...
# 1492    2021-02-15  2021-02-22 00:00:00                    L          MLO
# 1509    2019-12-29  2020-01-01 00:00:00                    R           CC
# 1510    2019-12-29  2020-01-01 00:00:00                    R          MLO
# 1511    2019-10-11  2019-10-15 00:00:00                    R           CC
# 1512    2019-10-11  2019-10-15 00:00:00                    R          MLO
#
#      FinalImageType                                    anon_dicom_path  \
# 1                2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/41737961/1...
# 4                2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/41737961/1...
# 5                2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/41737961/1...
# 12               2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/82818555/1...
# 13               2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/82818555/1...
# ...             ...                                                ...
# 1492             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/87877516/1...
# 1509             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/99703607/1...
# 1510             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/99703607/1...
# 1511             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/85936969/1...
# 1512             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/85936969/1...
#
#                                                png_path  \
# 1     /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 4     /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 5     /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 12    /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 13    /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# ...                                                 ...
# 1492  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1509  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1510  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1511  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1512  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
#
#                         StudyDescription           ProtocolName match_level  \
# 1          MG Diagnostic Mammo Bilateral                    RCC          []
# 4          MG Diagnostic Mammo Bilateral                   RMLO          []
# 5          MG Diagnostic Mammo Bilateral                   RMLO          []
# 12         MG Diagnostic Mammo Bilateral                    RCC          []
# 13         MG Diagnostic Mammo Bilateral                   RMCC          []
# ...                                  ...                    ...         ...
# 1492  MG Diagnostic Bilateral w/Tomo/CAD          L MLO ComboHD          []
# 1509           MG Diagnostic Right w/CAD                   R CC          []
# 1510           MG Diagnostic Right w/CAD                  R MLO          []
# 1511           MG Diagnostic Right w/CAD  3D_ROUTINE+2D_ROUTINE          []
# 1512           MG Diagnostic Right w/CAD  3D_ROUTINE+2D_ROUTINE          []
#
#       num_roi ROI_coords BreastImplantPresent
# 1           0         ()                   NO
# 4           0         ()                   NO
# 5           0         ()                   NO
# 12          0         ()                   NO
# 13          0         ()                   NO
# ...       ...        ...                  ...
# 1492        0         ()                   NO
# 1509        0         ()                   NO
# 1510        0         ()                   NO
# 1511        0         ()                   NO
# 1512        0         ()                   NO
#
# [806 rows x 21 columns]

# %%
print(f"ROIs  = {pos_group_images.num_roi.sum()}")
print(pos_group_images.num_roi.value_counts())
# Out:
# ROIs  = 9
# num_roi
# 0    798
# 1      7
# 2      1
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Excluding Images from the Negative Group that are found in the Positive Group using acc_anon and side

# %%
# Merge negatives and positive groups
neg_pos = pd.merge(
    neg_group_1yrfu_first_study_no_biopsy_images,
    pos_group_images,
    on=["empi_anon", "acc_anon", "side"],
    suffixes=["_neg", "_pos"],
)

# %%
# Create new KeyID of acc_anon + side on negative group and negative+positive group
neg_pos["acc_anon_side"] = neg_pos.acc_anon + neg_pos.side

# %%
neg_group_1yrfu_first_study_no_biopsy_images["acc_anon_side"] = (
    neg_group_1yrfu_first_study_no_biopsy_images.acc_anon
    + neg_group_1yrfu_first_study_no_biopsy_images.side
)
neg_group_1yrfu_first_study_no_biopsy_images.sample(2)
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 191619  68257398  6851799473747062      2017-04-04
# 103681  41789598  7175903704021652      2019-02-15
#
#                                             desc side asses path_severity  \
# 191619             MG Screening Right w/Tomo/CAD    R     N           NaN
# 103681  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#        bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 191619   NaN           NaN        NaN               R         NaN
# 103681   NaN           NaN        NaN               B         NaN
#
#        study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 191619                NaT     NaN     NaN      NaN              NaN      NaN
# 103681                NaT     NaN     NaN      NaN              NaN      NaN
#
#        procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 191619              NaN           NaN            NaN  2344311523037299
# 103681              NaN           NaN            NaN  4013836104088884
#
#        study_date_anon_1yrfu                                desc_1yrfu  \
# 191619            2018-11-03             MG Screening Right w/Tomo/CAD
# 103681            2020-05-01  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#        side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 191619          R           N                 NaN         NaN
# 103681          R           N                 NaN         NaN
#
#        procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 191619                 NaN              NaN                     R
# 103681                 NaN              NaN                     B
#
#         delta_date_1yrfu ImageLateralityFinal ViewPosition FinalImageType  \
# 191619               578                    R          MLO             2D
# 103681               441                    R          MLO             2D
#
#                                           anon_dicom_path  \
# 191619  /mnt/NAS2/mammo/anon_dicom/cohort_1/68257398/1...
# 103681  /mnt/NAS2/mammo/anon_dicom/cohort_1/41789598/1...
#
#                                                  png_path  \
# 191619  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 103681  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
#
#                                 StudyDescription   ProtocolName match_level  \
# 191619             MG Screening Right w/Tomo/CAD  R MLO ComboHD          []
# 103681  MG Screen Bilat w/Tomo/CAD Stnd Protocol  R MLO ComboHD          []
#
#         num_roi ROI_coords BreastImplantPresent      acc_anon_side
# 191619        0         ()                   NO  6851799473747062R
# 103681        0         ()                   NO  7175903704021652R

# %%
# Removing any images that are found in the positive group from the negative group using the created KeyID (acc_anon+side)
neg_group_final = neg_group_1yrfu_first_study_no_biopsy_images.loc[
    ~neg_group_1yrfu_first_study_no_biopsy_images.acc_anon_side.isin(
        neg_pos.acc_anon_side
    )
]
neg_group_final.sample(2)
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 63891   29634697  2990999232173615      2016-07-22
# 109261  43449548  2461020309035025      2016-12-09
#
#                                             desc side asses path_severity  \
# 63891   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 109261  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
#
#        bside procdate_anon           pdate_anon exam_laterality acc_anon_dx  \
# 63891    NaN           NaN                  NaN               B         NaN
# 109261     R    2016-12-26  2016-12-31 00:00:00               B         NaN
#
#        study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 63891                 NaT     NaN     NaN      NaN              NaN      NaN
# 109261                NaT     NaN     NaN      NaN              NaN      NaN
#
#        procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 63891               NaN           NaN            NaN  6070072192773336
# 109261              NaN           NaN            NaN  8862669239623990
#
#        study_date_anon_1yrfu                                desc_1yrfu  \
# 63891             2017-07-29  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 109261            2018-07-28  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#        side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 63891           L           N                 NaN         NaN
# 109261          L           N                 NaN         NaN
#
#        procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 63891                  NaN              NaN                     B
# 109261                 NaN              NaN                     B
#
#         delta_date_1yrfu ImageLateralityFinal ViewPosition FinalImageType  \
# 63891                372                    L          MLO             2D
# 109261               596                    L           CC             2D
#
#                                           anon_dicom_path  \
# 63891   /mnt/NAS2/mammo/anon_dicom/cohort_1/29634697/1...
# 109261  /mnt/NAS2/mammo/anon_dicom/cohort_1/43449548/1...
#
#                                                  png_path  \
# 63891   /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 109261  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
#
#                                 StudyDescription   ProtocolName match_level  \
# 63891   MG Screen Bilat w/Tomo/CAD Stnd Protocol  L MLO ComboHD          []
# 109261  MG Screen Bilat w/Tomo/CAD Stnd Protocol   L CC ComboHD          []
#
#         num_roi ROI_coords BreastImplantPresent      acc_anon_side
# 63891         0         ()                   NO  2990999232173615L
# 109261        0         ()                   NO  2461020309035025L

# %%
get_stats(neg_group_final)

print(f"ROIs  = {neg_group_final.num_roi.sum()}")
print(neg_group_final.num_roi.value_counts())
# Out:
# DF shape: (149727, 44)
# # Patients: 11243
# # Cases: 33180
#
# # Images: 149727
#
# ROIs  = 678
# num_roi
# 0    149116
# 1       555
# 2        46
# 3         9
# 4         1
# Name: count, dtype: int64

# %% [markdown]
# ## 9. Saving and Exporting

# %%
columns_to_save = [
    "empi_anon",
    "acc_anon",
    "anon_dicom_path",
    "desc",
    "ProtocolName",
    "asses",
    "path_severity",
    "study_date_anon",
    "side",
    "ImageLateralityFinal",
    "bside",
    "ViewPosition",
    "match_level",
    "num_roi",
    "ROI_coords",
]

# %%
get_stats(neg_group_final)
get_stats(pos_group_images)
has_overlap = neg_group_final["empi_anon"].isin(pos_group_images["empi_anon"]).any()
get_stats(pos_group_images)
if has_overlap:
    print("There are common patients.")
neg_group_final_filtered = neg_group_final[
    ~neg_group_final["empi_anon"].isin(pos_group_images["empi_anon"])
]
get_stats(neg_group_final_filtered)
get_stats(pos_group_images)
display(pos_group_images)
# Out:
# DF shape: (149727, 44)
# # Patients: 11243
# # Cases: 33180
#
# # Images: 149727
#
# DF shape: (806, 21)
# # Patients: 209
# # Cases: 303
#
# # Images: 806
#
# DF shape: (806, 21)
# # Patients: 209
# # Cases: 303
#
# # Images: 806
#
# There are common patients.
# DF shape: (149438, 44)
# # Patients: 11204
# # Cases: 33094
#
# # Images: 149438
#
# DF shape: (806, 21)
# # Patients: 209
# # Cases: 303
#
# # Images: 806
#      empi_anon          acc_anon cancer_diagnosis_date  \
# 1     41737961  3103295389430403            2013-01-10
# 4     41737961  3103295389430403            2013-01-10
# 5     41737961  3103295389430403            2013-01-10
# 12    82818555  9133832708678084            2013-11-10
# 13    82818555  9133832708678084            2013-11-10
# ...        ...               ...                   ...
# 1492  87877516  2183052495313832            2021-01-09
# 1509  99703607  1965937622916299            2019-12-08
# 1510  99703607  1965937622916299            2019-12-08
# 1511  85936969  4786838232916669            2019-09-10
# 1512  85936969  4786838232916669            2019-09-10
#
#                                     desc side asses path_severity bside  \
# 1          MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 4          MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 5          MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 12         MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# 13         MG Diagnostic Mammo Bilateral    R     K           NaN   NaN
# ...                                  ...  ...   ...           ...   ...
# 1492  MG Diagnostic Bilateral w/Tomo/CAD    L     K           0.0     L
# 1509           MG Diagnostic Right w/CAD    R     K           0.0     R
# 1510           MG Diagnostic Right w/CAD    R     K           0.0     R
# 1511           MG Diagnostic Right w/CAD    R     K           0.0     R
# 1512           MG Diagnostic Right w/CAD    R     K           0.0     R
#
#      procdate_anon           pdate_anon ImageLateralityFinal ViewPosition  \
# 1              NaN                  NaN                    R           CC
# 4              NaN                  NaN                    R          MLO
# 5              NaN                  NaN                    R          MLO
# 12             NaN                  NaN                    R           CC
# 13             NaN                  NaN                    R           CC
# ...            ...                  ...                  ...          ...
# 1492    2021-02-15  2021-02-22 00:00:00                    L          MLO
# 1509    2019-12-29  2020-01-01 00:00:00                    R           CC
# 1510    2019-12-29  2020-01-01 00:00:00                    R          MLO
# 1511    2019-10-11  2019-10-15 00:00:00                    R           CC
# 1512    2019-10-11  2019-10-15 00:00:00                    R          MLO
#
#      FinalImageType                                    anon_dicom_path  \
# 1                2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/41737961/1...
# 4                2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/41737961/1...
# 5                2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/41737961/1...
# 12               2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/82818555/1...
# 13               2D  /mnt/NAS2/mammo/anon_dicom/cohort_1/82818555/1...
# ...             ...                                                ...
# 1492             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/87877516/1...
# 1509             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/99703607/1...
# 1510             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/99703607/1...
# 1511             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/85936969/1...
# 1512             2D  /mnt/NAS2/mammo/anon_dicom/cohort_2/85936969/1...
#
#                                                png_path  \
# 1     /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 4     /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 5     /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 12    /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 13    /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# ...                                                 ...
# 1492  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1509  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1510  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1511  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1512  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
#
#                         StudyDescription           ProtocolName match_level  \
# 1          MG Diagnostic Mammo Bilateral                    RCC          []
# 4          MG Diagnostic Mammo Bilateral                   RMLO          []
# 5          MG Diagnostic Mammo Bilateral                   RMLO          []
# 12         MG Diagnostic Mammo Bilateral                    RCC          []
# 13         MG Diagnostic Mammo Bilateral                   RMCC          []
# ...                                  ...                    ...         ...
# 1492  MG Diagnostic Bilateral w/Tomo/CAD          L MLO ComboHD          []
# 1509           MG Diagnostic Right w/CAD                   R CC          []
# 1510           MG Diagnostic Right w/CAD                  R MLO          []
# 1511           MG Diagnostic Right w/CAD  3D_ROUTINE+2D_ROUTINE          []
# 1512           MG Diagnostic Right w/CAD  3D_ROUTINE+2D_ROUTINE          []
#
#       num_roi ROI_coords BreastImplantPresent
# 1           0         ()                   NO
# 4           0         ()                   NO
# 5           0         ()                   NO
# 12          0         ()                   NO
# 13          0         ()                   NO
# ...       ...        ...                  ...
# 1492        0         ()                   NO
# 1509        0         ()                   NO
# 1510        0         ()                   NO
# 1511        0         ()                   NO
# 1512        0         ()                   NO
#
# [806 rows x 21 columns]

# %%
# remove patients with breast implantat
# Find the patient IDs (empi_anon) with a breast implant
patients_with_implants = neg_group_final_filtered[
    neg_group_final_filtered["BreastImplantPresent"] == "YES"
]["empi_anon"].unique()

# Remove all rows for these patients
neg_group_final_filtered_final = neg_group_final_filtered[
    ~neg_group_final_filtered["empi_anon"].isin(patients_with_implants)
]
neg_group_final_filtered_final = neg_group_final_filtered_final[
    ~neg_group_final_filtered_final["ProtocolName"].str.contains(
        "SCC|SMLO|RMLOACIMF|RMLOAC|CCID|MLOID|MLOIMF|MCC|MLOAC|CCAC|MLOIDIMF|MLONP|CCNP|MLOAX|MLOAXIMF|TAN|CCRM|CCAX|CEDM|CESM|CCRL|MLOACNP|LMLOAC",
        case=False,
        na=False,
    )
    | neg_group_final_filtered_final["ProtocolName"].isna()
]
get_stats(neg_group_final_filtered_final)
display(neg_group_final_filtered_final)
# Out:
# DF shape: (135712, 44)
# # Patients: 10796
# # Cases: 31901
#
# # Images: 135712
#        empi_anon          acc_anon study_date_anon  \
# 0       10015693  1334581155737139      2015-10-11
# 1       10015693  1334581155737139      2015-10-11
# 4       10028836  7010941703189486      2014-09-03
# 7       10028836  7010941703189486      2014-09-03
# 9       10028836  7010941703189486      2014-09-03
# ...          ...               ...             ...
# 295917  99996622  5582628875236699      2014-07-24
# 295919  99999564  4369225803558884      2017-04-25
# 295921  99999564  4369225803558884      2017-04-25
# 295922  99999564  4369225803558884      2017-04-25
# 295924  99999564  4369225803558884      2017-04-25
#
#                                             desc side asses path_severity  \
# 0       MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 1       MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 4                         MG Screening Bilateral    L     N           NaN
# 7                         MG Screening Bilateral    L     N           NaN
# 9                         MG Screening Bilateral    R     N           NaN
# ...                                          ...  ...   ...           ...
# 295917  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     B           NaN
# 295919  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 295921  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 295922  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 295924  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#        bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 0        NaN           NaN        NaN               B         NaN
# 1        NaN           NaN        NaN               B         NaN
# 4        NaN           NaN        NaN               B         NaN
# 7        NaN           NaN        NaN               B         NaN
# 9        NaN           NaN        NaN               B         NaN
# ...      ...           ...        ...             ...         ...
# 295917   NaN           NaN        NaN               B         NaN
# 295919   NaN           NaN        NaN               B         NaN
# 295921   NaN           NaN        NaN               B         NaN
# 295922   NaN           NaN        NaN               B         NaN
# 295924   NaN           NaN        NaN               B         NaN
#
#        study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 0                     NaT     NaN     NaN      NaN              NaN      NaN
# 1                     NaT     NaN     NaN      NaN              NaN      NaN
# 4                     NaT     NaN     NaN      NaN              NaN      NaN
# 7                     NaT     NaN     NaN      NaN              NaN      NaN
# 9                     NaT     NaN     NaN      NaN              NaN      NaN
# ...                   ...     ...     ...      ...              ...      ...
# 295917                NaT     NaN     NaN      NaN              NaN      NaN
# 295919                NaT     NaN     NaN      NaN              NaN      NaN
# 295921                NaT     NaN     NaN      NaN              NaN      NaN
# 295922                NaT     NaN     NaN      NaN              NaN      NaN
# 295924                NaT     NaN     NaN      NaN              NaN      NaN
#
#        procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 0                   NaN           NaN            NaN  2281263876413228
# 1                   NaN           NaN            NaN  2281263876413228
# 4                   NaN           NaN            NaN  7270377379697338
# 7                   NaN           NaN            NaN  7270377379697338
# 9                   NaN           NaN            NaN  7270377379697338
# ...                 ...           ...            ...               ...
# 295917              NaN           NaN            NaN  9655172659462321
# 295919              NaN           NaN            NaN  8832872399780580
# 295921              NaN           NaN            NaN  8832872399780580
# 295922              NaN           NaN            NaN  8832872399780580
# 295924              NaN           NaN            NaN  8832872399780580
#
#        study_date_anon_1yrfu                                desc_1yrfu  \
# 0                 2018-01-06  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 1                 2018-01-06  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 4                 2015-12-30                    MG Screening Bilateral
# 7                 2015-12-30                    MG Screening Bilateral
# 9                 2015-12-30                    MG Screening Bilateral
# ...                      ...                                       ...
# 295917            2016-06-04  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 295919            2019-02-27  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 295921            2019-02-27  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 295922            2019-02-27  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 295924            2019-02-27  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#        side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 0               R           N                 NaN         NaN
# 1               R           N                 NaN         NaN
# 4               L           N                 NaN         NaN
# 7               L           N                 NaN         NaN
# 9               R           N                 NaN         NaN
# ...           ...         ...                 ...         ...
# 295917          R           N                 NaN         NaN
# 295919          L           N                 NaN         NaN
# 295921          L           N                 NaN         NaN
# 295922          R           N                 NaN         NaN
# 295924          R           N                 NaN         NaN
#
#        procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 0                      NaN              NaN                     B
# 1                      NaN              NaN                     B
# 4                      NaN              NaN                     B
# 7                      NaN              NaN                     B
# 9                      NaN              NaN                     B
# ...                    ...              ...                   ...
# 295917                 NaN              NaN                     B
# 295919                 NaN              NaN                     B
# 295921                 NaN              NaN                     B
# 295922                 NaN              NaN                     B
# 295924                 NaN              NaN                     B
#
#         delta_date_1yrfu ImageLateralityFinal ViewPosition FinalImageType  \
# 0                    818                    R          MLO             2D
# 1                    818                    R           CC             2D
# 4                    483                    L           CC             2D
# 7                    483                    L          MLO             2D
# 9                    483                    R          MLO             2D
# ...                  ...                  ...          ...            ...
# 295917               681                    R           CC             2D
# 295919               673                    L           CC             2D
# 295921               673                    L          MLO             2D
# 295922               673                    R           CC             2D
# 295924               673                    R          MLO             2D
#
#                                           anon_dicom_path  \
# 0       /mnt/NAS2/mammo/anon_dicom/cohort_1/10015693/1...
# 1       /mnt/NAS2/mammo/anon_dicom/cohort_1/10015693/1...
# 4       /mnt/NAS2/mammo/anon_dicom/cohort_1/10028836/1...
# 7       /mnt/NAS2/mammo/anon_dicom/cohort_1/10028836/1...
# 9       /mnt/NAS2/mammo/anon_dicom/cohort_1/10028836/1...
# ...                                                   ...
# 295917  /mnt/NAS2/mammo/anon_dicom/cohort_1/99996622/1...
# 295919  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...
# 295921  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...
# 295922  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...
# 295924  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...
#
#                                                  png_path  \
# 0       /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 1       /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 4       /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 7       /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 9       /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# ...                                                   ...
# 295917  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 295919  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 295921  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 295922  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 295924  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
#
#                                 StudyDescription   ProtocolName match_level  \
# 0       MG Screen Bilat w/Tomo/CAD Stnd Protocol  R MLO ComboHD          []
# 1       MG Screen Bilat w/Tomo/CAD Stnd Protocol   R CC ComboHD          []
# 4                         MG Screening Bilateral           L CC          []
# 7                         MG Screening Bilateral          L MLO          []
# 9                         MG Screening Bilateral          R MLO          []
# ...                                          ...            ...         ...
# 295917  MG Screen Bilat w/Tomo/CAD Stnd Protocol     R CC Combo          []
# 295919  MG Screen Bilat w/Tomo/CAD Stnd Protocol     L CC Combo          []
# 295921  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L MLO Combo          []
# 295922  MG Screen Bilat w/Tomo/CAD Stnd Protocol     R CC Combo          []
# 295924  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R MLO Combo          []
#
#         num_roi ROI_coords BreastImplantPresent      acc_anon_side
# 0             0         ()                   NO  1334581155737139R
# 1             0         ()                   NO  1334581155737139R
# 4             0         ()                   NO  7010941703189486L
# 7             0         ()                   NO  7010941703189486L
# 9             0         ()                   NO  7010941703189486R
# ...         ...        ...                  ...                ...
# 295917        0         ()                   NO  5582628875236699R
# 295919        0         ()                   NO  4369225803558884L
# 295921        0         ()                   NO  4369225803558884L
# 295922        0         ()                   NO  4369225803558884R
# 295924        0         ()                   NO  4369225803558884R
#
# [135712 rows x 44 columns]

# %%
# keep only patients of the negative group with enough 5 years follow up
neg_group_final_filtered_final.study_date_anon = pd.to_datetime(
    neg_group_final_filtered_final.study_date_anon, errors="coerce"
)

follow_up_period = neg_group_final_filtered_final.groupby("empi_anon")[
    "study_date_anon"
].agg(["min", "max"])
follow_up_period["duration_years"] = (
    follow_up_period["max"].dt.year - follow_up_period["min"].dt.year
)
patients_with_5_years = follow_up_period[follow_up_period["duration_years"] >= 5]
valid_patients = patients_with_5_years.index

neg_group_final_5_years = neg_group_final_filtered_final[
    neg_group_final_filtered_final["empi_anon"].isin(valid_patients)
].reset_index(drop=True)
get_stats(neg_group_final_5_years)
display(neg_group_final_5_years)
# Out:
# DF shape: (56233, 44)
# # Patients: 2409
# # Cases: 13011
#
# # Images: 56233
#       empi_anon          acc_anon study_date_anon  \
# 0      10093833  2030506250163251      2013-06-21
# 1      10093833  2030506250163251      2013-06-21
# 2      10093833  2030506250163251      2013-06-21
# 3      10093833  2030506250163251      2013-06-21
# 4      10093833  2500827897014911      2014-07-02
# ...         ...               ...             ...
# 56228  99986224  8107409307566891      2018-05-22
# 56229  99986224  9061973132112039      2013-04-10
# 56230  99986224  9061973132112039      2013-04-10
# 56231  99986224  9061973132112039      2013-04-10
# 56232  99986224  9061973132112039      2013-04-10
#
#                                            desc side asses path_severity  \
# 0                  MG Screening Bilateral w/CAD    L     N           NaN
# 1                  MG Screening Bilateral w/CAD    L     N           NaN
# 2                  MG Screening Bilateral w/CAD    R     N           NaN
# 3                  MG Screening Bilateral w/CAD    R     N           NaN
# 4                  MG Screening Bilateral w/CAD    L     N           NaN
# ...                                         ...  ...   ...           ...
# 56228  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 56229              MG Screening Bilateral w/CAD    L     N           NaN
# 56230              MG Screening Bilateral w/CAD    L     N           NaN
# 56231              MG Screening Bilateral w/CAD    R     N           NaN
# 56232              MG Screening Bilateral w/CAD    R     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 0       NaN           NaN        NaN               B         NaN
# 1       NaN           NaN        NaN               B         NaN
# 2       NaN           NaN        NaN               B         NaN
# 3       NaN           NaN        NaN               B         NaN
# 4       NaN           NaN        NaN               B         NaN
# ...     ...           ...        ...             ...         ...
# 56228   NaN           NaN        NaN               B         NaN
# 56229   NaN           NaN        NaN               B         NaN
# 56230   NaN           NaN        NaN               B         NaN
# 56231   NaN           NaN        NaN               B         NaN
# 56232   NaN           NaN        NaN               B         NaN
#
#       study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 0                    NaT     NaN     NaN      NaN              NaN      NaN
# 1                    NaT     NaN     NaN      NaN              NaN      NaN
# 2                    NaT     NaN     NaN      NaN              NaN      NaN
# 3                    NaT     NaN     NaN      NaN              NaN      NaN
# 4                    NaT     NaN     NaN      NaN              NaN      NaN
# ...                  ...     ...     ...      ...              ...      ...
# 56228                NaT     NaN     NaN      NaN              NaN      NaN
# 56229                NaT     NaN     NaN      NaN              NaN      NaN
# 56230                NaT     NaN     NaN      NaN              NaN      NaN
# 56231                NaT     NaN     NaN      NaN              NaN      NaN
# 56232                NaT     NaN     NaN      NaN              NaN      NaN
#
#       procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 0                  NaN           NaN            NaN  2500827897014911
# 1                  NaN           NaN            NaN  2500827897014911
# 2                  NaN           NaN            NaN  6488770689649000
# 3                  NaN           NaN            NaN  6488770689649000
# 4                  NaN           NaN            NaN  6488770689649000
# ...                ...           ...            ...               ...
# 56228              NaN           NaN            NaN  8848125344172315
# 56229              NaN           NaN            NaN  1388973192449589
# 56230              NaN           NaN            NaN  1388973192449589
# 56231              NaN           NaN            NaN  1388973192449589
# 56232              NaN           NaN            NaN  1388973192449589
#
#       study_date_anon_1yrfu                                desc_1yrfu  \
# 0                2014-07-02              MG Screening Bilateral w/CAD
# 1                2014-07-02              MG Screening Bilateral w/CAD
# 2                2015-07-24  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 3                2015-07-24  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 4                2015-07-24  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# ...                     ...                                       ...
# 56228            2019-08-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 56229            2015-04-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 56230            2015-04-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 56231            2015-04-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 56232            2015-04-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#       side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 0              L           N                 NaN         NaN
# 1              L           N                 NaN         NaN
# 2              R           N                 NaN         NaN
# 3              R           N                 NaN         NaN
# 4              L           N                 NaN         NaN
# ...          ...         ...                 ...         ...
# 56228          R           N                 NaN         NaN
# 56229          L           N                 NaN         NaN
# 56230          L           N                 NaN         NaN
# 56231          R           N                 NaN         NaN
# 56232          R           N                 NaN         NaN
#
#       procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 0                     NaN              NaN                     B
# 1                     NaN              NaN                     B
# 2                     NaN              NaN                     B
# 3                     NaN              NaN                     B
# 4                     NaN              NaN                     B
# ...                   ...              ...                   ...
# 56228                 NaN              NaN                     B
# 56229                 NaN              NaN                     B
# 56230                 NaN              NaN                     B
# 56231                 NaN              NaN                     B
# 56232                 NaN              NaN                     B
#
#        delta_date_1yrfu ImageLateralityFinal ViewPosition FinalImageType  \
# 0                   376                    L           CC             2D
# 1                   376                    L          MLO             2D
# 2                   763                    R          MLO             2D
# 3                   763                    R           CC             2D
# 4                   387                    L           CC             2D
# ...                 ...                  ...          ...            ...
# 56228               460                    R           CC             2D
# 56229               745                    L          MLO             2D
# 56230               745                    L           CC             2D
# 56231               745                    R           CC             2D
# 56232               745                    R          MLO             2D
#
#                                          anon_dicom_path  \
# 0      /mnt/NAS2/mammo/anon_dicom/cohort_2/10093833/1...
# 1      /mnt/NAS2/mammo/anon_dicom/cohort_2/10093833/1...
# 2      /mnt/NAS2/mammo/anon_dicom/cohort_2/10093833/1...
# 3      /mnt/NAS2/mammo/anon_dicom/cohort_2/10093833/1...
# 4      /mnt/NAS2/mammo/anon_dicom/cohort_2/10093833/1...
# ...                                                  ...
# 56228  /mnt/NAS2/mammo/anon_dicom/cohort_1/99986224/1...
# 56229  /mnt/NAS2/mammo/anon_dicom/cohort_1/99986224/1...
# 56230  /mnt/NAS2/mammo/anon_dicom/cohort_1/99986224/1...
# 56231  /mnt/NAS2/mammo/anon_dicom/cohort_1/99986224/1...
# 56232  /mnt/NAS2/mammo/anon_dicom/cohort_1/99986224/1...
#
#                                                 png_path  \
# 0      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 2      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 3      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 4      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# ...                                                  ...
# 56228  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 56229  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 56230  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 56231  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 56232  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
#
#                                StudyDescription  ProtocolName match_level  \
# 0                  MG Screening Bilateral w/CAD          L CC          []
# 1                  MG Screening Bilateral w/CAD         L MLO          []
# 2                  MG Screening Bilateral w/CAD         R MLO          []
# 3                  MG Screening Bilateral w/CAD          R CC          []
# 4                  MG Screening Bilateral w/CAD          L CC          []
# ...                                         ...           ...         ...
# 56228  MG Screen Bilat w/Tomo/CAD Stnd Protocol  R CC ComboHD          []
# 56229              MG Screening Bilateral w/CAD         L MLO          []
# 56230              MG Screening Bilateral w/CAD          L CC          []
# 56231              MG Screening Bilateral w/CAD          R CC          []
# 56232              MG Screening Bilateral w/CAD         R MLO          []
#
#        num_roi ROI_coords BreastImplantPresent      acc_anon_side
# 0            0         ()                   NO  2030506250163251L
# 1            0         ()                   NO  2030506250163251L
# 2            0         ()                   NO  2030506250163251R
# 3            0         ()                   NO  2030506250163251R
# 4            0         ()                   NO  2500827897014911L
# ...        ...        ...                  ...                ...
# 56228        0         ()                   NO  8107409307566891R
# 56229        0         ()                   NO  9061973132112039L
# 56230        0         ()                   NO  9061973132112039L
# 56231        0         ()                   NO  9061973132112039R
# 56232        0         ()                   NO  9061973132112039R
#
# [56233 rows x 44 columns]

# %%
def anon_dicom_path_fix(DICOMPathStr):
    return DICOMPathStr.replace("/mnt/NAS2/mammo/anon_dicom", "/storage2/images")


result_df_neg_group_final_new_path = neg_group_final_5_years.copy()
result_df_neg_group_final_new_path["anon_dicom_path_local"] = (
    result_df_neg_group_final_new_path["anon_dicom_path"].apply(anon_dicom_path_fix)
)
result_df_neg_group_final_new_path = result_df_neg_group_final_new_path.drop(
    columns=["anon_dicom_path"]
)
result_df_neg_group_final_new_path = result_df_neg_group_final_new_path.rename(
    columns={"anon_dicom_path_local": "anon_dicom_path"}
)

display(result_df_neg_group_final_new_path)
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 0      10093833  2030506250163251      2013-06-21
# 1      10093833  2030506250163251      2013-06-21
# 2      10093833  2030506250163251      2013-06-21
# 3      10093833  2030506250163251      2013-06-21
# 4      10093833  2500827897014911      2014-07-02
# ...         ...               ...             ...
# 56228  99986224  8107409307566891      2018-05-22
# 56229  99986224  9061973132112039      2013-04-10
# 56230  99986224  9061973132112039      2013-04-10
# 56231  99986224  9061973132112039      2013-04-10
# 56232  99986224  9061973132112039      2013-04-10
#
#                                            desc side asses path_severity  \
# 0                  MG Screening Bilateral w/CAD    L     N           NaN
# 1                  MG Screening Bilateral w/CAD    L     N           NaN
# 2                  MG Screening Bilateral w/CAD    R     N           NaN
# 3                  MG Screening Bilateral w/CAD    R     N           NaN
# 4                  MG Screening Bilateral w/CAD    L     N           NaN
# ...                                         ...  ...   ...           ...
# 56228  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 56229              MG Screening Bilateral w/CAD    L     N           NaN
# 56230              MG Screening Bilateral w/CAD    L     N           NaN
# 56231              MG Screening Bilateral w/CAD    R     N           NaN
# 56232              MG Screening Bilateral w/CAD    R     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 0       NaN           NaN        NaN               B         NaN
# 1       NaN           NaN        NaN               B         NaN
# 2       NaN           NaN        NaN               B         NaN
# 3       NaN           NaN        NaN               B         NaN
# 4       NaN           NaN        NaN               B         NaN
# ...     ...           ...        ...             ...         ...
# 56228   NaN           NaN        NaN               B         NaN
# 56229   NaN           NaN        NaN               B         NaN
# 56230   NaN           NaN        NaN               B         NaN
# 56231   NaN           NaN        NaN               B         NaN
# 56232   NaN           NaN        NaN               B         NaN
#
#       study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 0                    NaT     NaN     NaN      NaN              NaN      NaN
# 1                    NaT     NaN     NaN      NaN              NaN      NaN
# 2                    NaT     NaN     NaN      NaN              NaN      NaN
# 3                    NaT     NaN     NaN      NaN              NaN      NaN
# 4                    NaT     NaN     NaN      NaN              NaN      NaN
# ...                  ...     ...     ...      ...              ...      ...
# 56228                NaT     NaN     NaN      NaN              NaN      NaN
# 56229                NaT     NaN     NaN      NaN              NaN      NaN
# 56230                NaT     NaN     NaN      NaN              NaN      NaN
# 56231                NaT     NaN     NaN      NaN              NaN      NaN
# 56232                NaT     NaN     NaN      NaN              NaN      NaN
#
#       procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 0                  NaN           NaN            NaN  2500827897014911
# 1                  NaN           NaN            NaN  2500827897014911
# 2                  NaN           NaN            NaN  6488770689649000
# 3                  NaN           NaN            NaN  6488770689649000
# 4                  NaN           NaN            NaN  6488770689649000
# ...                ...           ...            ...               ...
# 56228              NaN           NaN            NaN  8848125344172315
# 56229              NaN           NaN            NaN  1388973192449589
# 56230              NaN           NaN            NaN  1388973192449589
# 56231              NaN           NaN            NaN  1388973192449589
# 56232              NaN           NaN            NaN  1388973192449589
#
#       study_date_anon_1yrfu                                desc_1yrfu  \
# 0                2014-07-02              MG Screening Bilateral w/CAD
# 1                2014-07-02              MG Screening Bilateral w/CAD
# 2                2015-07-24  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 3                2015-07-24  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 4                2015-07-24  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# ...                     ...                                       ...
# 56228            2019-08-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 56229            2015-04-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 56230            2015-04-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 56231            2015-04-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 56232            2015-04-25  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#       side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 0              L           N                 NaN         NaN
# 1              L           N                 NaN         NaN
# 2              R           N                 NaN         NaN
# 3              R           N                 NaN         NaN
# 4              L           N                 NaN         NaN
# ...          ...         ...                 ...         ...
# 56228          R           N                 NaN         NaN
# 56229          L           N                 NaN         NaN
# 56230          L           N                 NaN         NaN
# 56231          R           N                 NaN         NaN
# 56232          R           N                 NaN         NaN
#
#       procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 0                     NaN              NaN                     B
# 1                     NaN              NaN                     B
# 2                     NaN              NaN                     B
# 3                     NaN              NaN                     B
# 4                     NaN              NaN                     B
# ...                   ...              ...                   ...
# 56228                 NaN              NaN                     B
# 56229                 NaN              NaN                     B
# 56230                 NaN              NaN                     B
# 56231                 NaN              NaN                     B
# 56232                 NaN              NaN                     B
#
#        delta_date_1yrfu ImageLateralityFinal ViewPosition FinalImageType  \
# 0                   376                    L           CC             2D
# 1                   376                    L          MLO             2D
# 2                   763                    R          MLO             2D
# 3                   763                    R           CC             2D
# 4                   387                    L           CC             2D
# ...                 ...                  ...          ...            ...
# 56228               460                    R           CC             2D
# 56229               745                    L          MLO             2D
# 56230               745                    L           CC             2D
# 56231               745                    R           CC             2D
# 56232               745                    R          MLO             2D
#
#                                                 png_path  \
# 0      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 1      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 2      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 3      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 4      /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# ...                                                  ...
# 56228  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 56229  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 56230  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 56231  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 56232  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
#
#                                StudyDescription  ProtocolName match_level  \
# 0                  MG Screening Bilateral w/CAD          L CC          []
# 1                  MG Screening Bilateral w/CAD         L MLO          []
# 2                  MG Screening Bilateral w/CAD         R MLO          []
# 3                  MG Screening Bilateral w/CAD          R CC          []
# 4                  MG Screening Bilateral w/CAD          L CC          []
# ...                                         ...           ...         ...
# 56228  MG Screen Bilat w/Tomo/CAD Stnd Protocol  R CC ComboHD          []
# 56229              MG Screening Bilateral w/CAD         L MLO          []
# 56230              MG Screening Bilateral w/CAD          L CC          []
# 56231              MG Screening Bilateral w/CAD          R CC          []
# 56232              MG Screening Bilateral w/CAD         R MLO          []
#
#        num_roi ROI_coords BreastImplantPresent      acc_anon_side  \
# 0            0         ()                   NO  2030506250163251L
# 1            0         ()                   NO  2030506250163251L
# 2            0         ()                   NO  2030506250163251R
# 3            0         ()                   NO  2030506250163251R
# 4            0         ()                   NO  2500827897014911L
# ...        ...        ...                  ...                ...
# 56228        0         ()                   NO  8107409307566891R
# 56229        0         ()                   NO  9061973132112039L
# 56230        0         ()                   NO  9061973132112039L
# 56231        0         ()                   NO  9061973132112039R
# 56232        0         ()                   NO  9061973132112039R
#
#                                          anon_dicom_path
# 0      /storage2/images/cohort_2/10093833/1.2.846.113...
# 1      /storage2/images/cohort_2/10093833/1.2.846.113...
# 2      /storage2/images/cohort_2/10093833/1.2.846.113...
# 3      /storage2/images/cohort_2/10093833/1.2.846.113...
# 4      /storage2/images/cohort_2/10093833/1.2.842.113...
# ...                                                  ...
# 56228  /storage2/images/cohort_1/99986224/1.2.843.113...
# 56229  /storage2/images/cohort_1/99986224/1.2.843.113...
# 56230  /storage2/images/cohort_1/99986224/1.2.843.113...
# 56231  /storage2/images/cohort_1/99986224/1.2.843.113...
# 56232  /storage2/images/cohort_1/99986224/1.2.843.113...
#
# [56233 rows x 44 columns]

# %%
result_df_neg_group_final_new_path[columns_to_save].to_csv(
    "NEGATIVE_GROUP_FINAL.csv", index=False
)

# %%
import pandas as pd

neg_path = "/content/NEGATIVE_GROUP_FINAL.csv"
df_neg_group = pd.read_csv(neg_path)
get_stats(df_neg_group)
# Out:
# DF shape: (56233, 15)
# # Patients: 2409
# # Cases: 13011
#
# # Images: 56233

# %%
# Step 1: Define a helper function to determine rows to keep
def filter_images(group):
    # Count protocol frequencies within the examination
    protocol_counts = group["ProtocolName"].value_counts()

    # Add protocol frequency column
    group["ProtocolFrequency"] = group["ProtocolName"].map(protocol_counts)

    # Sort by ViewPosition, ProtocolFrequency, and keep first occurrence if there's a tie
    group = group.sort_values(
        by=["ViewPosition", "ProtocolFrequency"], ascending=[True, False]
    )
    group = group.drop_duplicates(
        subset=["ImageLateralityFinal", "ViewPosition"], keep="last"
    )
    # Drop the helper column before returning
    group = group.drop(columns=["ProtocolFrequency"])
    return group


# Step 2: Apply the helper function group-wise
result_df_neg_group = df_neg_group.groupby(
    ["empi_anon", "acc_anon"], group_keys=False
).apply(filter_images)
# Step 3: Reset index if necessary
result_df_neg_group = result_df_neg_group.reset_index(drop=True)
# Out:
# <ipython-input-11-a3b6cd43e8f9>:17: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df_neg_group = df_neg_group.groupby(["empi_anon", "acc_anon"], group_keys=False).apply(filter_images)

# %%
get_stats(result_df_neg_group)
display(result_df_neg_group)
# Out:
# DF shape: (49355, 15)
# # Patients: 2409
# # Cases: 13011
#
# # Images: 49355
#        empi_anon          acc_anon  \
# 0       10093833  2030506250163251
# 1       10093833  2030506250163251
# 2       10093833  2030506250163251
# 3       10093833  2030506250163251
# 4       10093833  2500827897014911
# ...          ...               ...
# 49350   99986224  8107409307566891
# 49351   99986224  9061973132112039
# 49352   99986224  9061973132112039
# 49353   99986224  9061973132112039
# 49354   99986224  9061973132112039
#
#                                          anon_dicom_path  \
# 0      /storage2/images/cohort_2/10093833/1.2.846.113...
# 1      /storage2/images/cohort_2/10093833/1.2.846.113...
# 2      /storage2/images/cohort_2/10093833/1.2.846.113...
# 3      /storage2/images/cohort_2/10093833/1.2.846.113...
# 4      /storage2/images/cohort_2/10093833/1.2.842.113...
# ...                                                  ...
# 49350  /storage2/images/cohort_1/99986224/1.2.843.113...
# 49351  /storage2/images/cohort_1/99986224/1.2.843.113...
# 49352  /storage2/images/cohort_1/99986224/1.2.843.113...
# 49353  /storage2/images/cohort_1/99986224/1.2.843.113...
# 49354  /storage2/images/cohort_1/99986224/1.2.843.113...
#
#                                            desc   ProtocolName asses  \
# 0                  MG Screening Bilateral w/CAD           L CC     N
# 1                  MG Screening Bilateral w/CAD           R CC     N
# 2                  MG Screening Bilateral w/CAD          L MLO     N
# 3                  MG Screening Bilateral w/CAD          R MLO     N
# 4                  MG Screening Bilateral w/CAD           L CC     N
# ...                                         ...            ...   ...
# 49350  MG Screen Bilat w/Tomo/CAD Stnd Protocol  R MLO ComboHD     N
# 49351              MG Screening Bilateral w/CAD           L CC     N
# 49352              MG Screening Bilateral w/CAD           R CC     N
# 49353              MG Screening Bilateral w/CAD          L MLO     N
# 49354              MG Screening Bilateral w/CAD          R MLO     N
#
#        path_severity study_date_anon side ImageLateralityFinal bside  \
# 0                NaN      2013-06-21    L                    L   NaN
# 1                NaN      2013-06-21    R                    R   NaN
# 2                NaN      2013-06-21    L                    L   NaN
# 3                NaN      2013-06-21    R                    R   NaN
# 4                NaN      2014-07-02    L                    L   NaN
# ...              ...             ...  ...                  ...   ...
# 49350            NaN      2018-05-22    R                    R   NaN
# 49351            NaN      2013-04-10    L                    L   NaN
# 49352            NaN      2013-04-10    R                    R   NaN
# 49353            NaN      2013-04-10    L                    L   NaN
# 49354            NaN      2013-04-10    R                    R   NaN
#
#       ViewPosition match_level  num_roi ROI_coords
# 0               CC          []        0         ()
# 1               CC          []        0         ()
# 2              MLO          []        0         ()
# 3              MLO          []        0         ()
# 4               CC          []        0         ()
# ...            ...         ...      ...        ...
# 49350          MLO          []        0         ()
# 49351           CC          []        0         ()
# 49352           CC          []        0         ()
# 49353          MLO          []        0         ()
# 49354          MLO          []        0         ()
#
# [49355 rows x 15 columns]

# %%
result_df_neg_group.to_csv("NEGATIVE_GROUP_FINAL_2.csv", index=False)

# %% [markdown]
# # END
